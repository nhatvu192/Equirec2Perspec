# %%
# %load_ext autoreload
# %autoreload 2

import os
import cv2 
import Equirec2Perspec as E2P
import Perspec2Equirec as P2E
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
equ = E2P.Equirectangular('src/image.jpg')    # Load equirectangular image
img = equ.GetPerspective(60, 100, 0, 720, 1080) # Specify parameters(FOV, theta, phi, height, width)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
FOV, THETA, PHI = 60, -100, 0
equ = E2P.Equirectangular('src/image.jpg')    # Load equirectangular image
img = equ.GetPerspective(FOV, THETA, PHI, 720, 1080)
persp = P2E.Perspective(img)
equi = persp.GetEquirectangular(FOV,THETA,PHI, equ._height, equ._width)

# %%
plt.imshow(equi)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 equi.isna()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'isna'
